# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import neurokit2 as nk
# import scipy

# %%
def read_ecg(path: str):
    return

# %%
def generate_ecg():
    return

# %%
freq = 250
ecg_signal = nk.ecg_simulate(duration=5, sampling_rate=freq)

# %%
fig, ax = plt.subplots()
ax.plot(np.arange(0, len(ecg_signal) / 250, 1 / 250), ecg_signal)

# %%
ax.clear()
fig
